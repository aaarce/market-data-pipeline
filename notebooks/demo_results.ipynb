# %% [markdown]
# # Demo: Market Features CSV\nRun the pipeline first:\n\n```bash\npython -m src.cli --config config.yaml\npython -m src.viz --config config.yaml\n```\n

# %%
import pandas as pd\ndf = pd.read_csv('data/processed/market_features.csv')\ndf.head()\n
